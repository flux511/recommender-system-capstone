# %% [markdown]
# # Creating a wordcloud

# %%
# installation of wordcloud
# pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1.tar.gz (220 kB)
#      |████████████████████████████████| 220 kB 1.9 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: pillow in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/janaconradi/neuefische/recommender-system-capstone/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Using legacy 'setup.py install' for wordcloud, since package 'wheel' is not installed.
# Installing collected packages: wordcloud
#     Running setup.py install for wordcloud ... done
# Successfully installed wordcloud-1.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# import data
df_features = pd.read_csv("../data/df_features.csv")

# %%
# check out the data
df_features.head()
# Out:
#    movieId  tmdbId                                             actors  \
# 0        1     862  Tom Hanks Tim Allen Don Rickles Jim Varney Wal...
# 1        2    8844  Robin Williams Jonathan Hyde Kirsten Dunst Bra...
# 2        3   15602  Walter Matthau Jack Lemmon Ann-Margret Sophia ...
# 3        4   31357  Whitney Houston Angela Bassett Loretta Devine ...
# 4        5   11862  Steve Martin Diane Keaton Martin Short Kimberl...
#
#                                             keywords  \
# 0  jealousy toy boy friendship friends rivalry bo...
# 1  board game disappearance based on children's b...
# 2   fishing best friend duringcreditsstinger old men
# 3  based on novel interracial relationship single...
# 4  baby midlife crisis confidence aging daughter ...
#
#                                            crew_jobs  \
# 0  ['Director', 'Screenplay', 'Screenplay', 'Scre...
# 1  ['Executive Producer', 'Screenplay', 'Original...
# 2  ['Director', 'Characters', 'Writer', 'Sound Re...
# 3  ['Director', 'Screenplay', 'Producer', 'Produc...
# 4  ['Original Music Composer', 'Director of Photo...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                             overview  release_date  \
# 0  ['Led', 'by', 'Woody,', "Andy's", 'toys', 'liv...        1995.0
# 1  ['When', 'siblings', 'Judy', 'and', 'Peter', '...        1995.0
# 2  ['A', 'family', 'wedding', 'reignites', 'the',...        1995.0
# 3  ['Cheated', 'on,', 'mistreated', 'and', 'stepp...        1995.0
# 4  ['Just', 'when', 'George', 'Banks', 'has', 're...        1995.0
#
#                                              tagline  \
# 0
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  imdbId  \
# 0                    Toy Story  114709
# 1                      Jumanji  113497
# 2             Grumpier Old Men  113228
# 3            Waiting to Exhale  114885
# 4  Father of the Bride Part II  113041
#
#                                     stemmed_overview
# 0  led by woody, andi toy live happili in his roo...
# 1  when sibl judi and peter discov an enchant boa...
# 2  a famili wed reignit the ancient feud between ...
# 3  cheat on, mistreat and step on, the women are ...
# 4  just when georg bank has recov from his daught...

# %% [markdown]
# ## Short cleaning of keywords

# %%
df_features['keywords'].filter(regex='^nan')
# Out:
# Series([], Name: keywords, dtype: object)

# %%
df_features['keywords'] = df_features['keywords'].dropna()

# %% [markdown]
# ## Pre-processing of text

# %%
df_features['title'] = df_features['title'].astype('str')
df_features['overview'] = df_features['overview'].astype('str')
df_features['keywords'] = df_features['keywords'].astype('str')

# %%
title_corpus = ' '.join(df_features['title'])
overview_corpus = ' '.join(df_features['overview'])
keyword_corpus = ' '.join(df_features['keywords'])

# %%
keyword_corpus.find("nan")
keyword_corpus = keyword_corpus.replace("nan", "")
keyword_corpus = keyword_corpus.replace("based", "")

# %%
keyword_corpus = keyword_corpus.replace("based", "")

# %% [markdown]
# # Wordcloud of the Title

# %%
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(title_corpus)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Wordcloud of the overview

# %%
overview_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Wordcloud of Keywords

# %%
keyword_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000, collocations=False).generate(keyword_corpus)
plt.figure(figsize=(16,8))
plt.imshow(keyword_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Wordcloud of Genres

# %%
df_features['genres'] = df_features['genres'].astype('str')
genres_corpus = ' '.join(df_features['genres'])

# %%
genres_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000, collocations=False).generate(genres_corpus)
plt.figure(figsize=(8,4))
plt.imshow(genres_wordcloud)
plt.axis('off')
plt.show()
